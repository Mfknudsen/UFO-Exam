# %%
import pandas as pd;
import matplotlib.pyplot as plt;
import numpy as np;
import json;
import seaborn as sns;

# %%
with open('JsonFiles/S 1.json') as user_file:
    jsonS1 = json.load(user_file)
with open('JsonFiles/S 2.json') as user_file:
    jsonS2 = json.load(user_file)
with open('JsonFiles/S 3.json') as user_file:
    jsonS3 = json.load(user_file)
with open('JsonFiles/S 4.json') as user_file:
    jsonS4 = json.load(user_file)
with open('JsonFiles/S 5.json') as user_file:
    jsonS5 = json.load(user_file)               

with open('JsonFiles/M 1.json') as user_file:
    jsonM1 = json.load(user_file)
with open('JsonFiles/M 2.json') as user_file:
    jsonM2 = json.load(user_file)
with open('JsonFiles/M 3.json') as user_file:
    jsonM3 = json.load(user_file)
with open('JsonFiles/M 4.json') as user_file:
    jsonM4 = json.load(user_file)
with open('JsonFiles/M 5.json') as user_file:
    jsonM5 = json.load(user_file)                

with open('JsonFiles/L 1.json') as user_file:
    jsonL1 = json.load(user_file)
with open('JsonFiles/L 2.json') as user_file:
    jsonL2 = json.load(user_file)
with open('JsonFiles/L 3.json') as user_file:
    jsonL3 = json.load(user_file)
with open('JsonFiles/L 4.json') as user_file:
    jsonL4 = json.load(user_file)
with open('JsonFiles/L 5.json') as user_file:
    jsonL5 = json.load(user_file)

# %%
#Small data set results from C++
cppS1 = pd.read_csv("CppResults/S 1.csv")
cppS2 = pd.read_csv("CppResults/S 2.csv")
cppS3 = pd.read_csv("CppResults/S 3.csv")
cppS4 = pd.read_csv("CppResults/S 4.csv")
cppS5 = pd.read_csv("CppResults/S 5.csv")

#Medium data set results from C++
cppM1 = pd.read_csv("CppResults/M 1.csv")
cppM2 = pd.read_csv("CppResults/M 2.csv")
cppM3 = pd.read_csv("CppResults/M 3.csv")
cppM4 = pd.read_csv("CppResults/M 4.csv")
cppM5 = pd.read_csv("CppResults/M 5.csv")

#Large data set results from C++
cppL1 = pd.read_csv("CppResults/L 1.csv")
cppL2 = pd.read_csv("CppResults/L 2.csv")
cppL3 = pd.read_csv("CppResults/L 3.csv")
cppL4 = pd.read_csv("CppResults/L 4.csv")
cppL5 = pd.read_csv("CppResults/L 5.csv")

# %%
#Small data set results from C#
csS1 = pd.read_csv("CSharpResults/S 1.csv")
csS2 = pd.read_csv("CSharpResults/S 2.csv")
csS3 = pd.read_csv("CSharpResults/S 3.csv")
csS4 = pd.read_csv("CSharpResults/S 4.csv")
csS5 = pd.read_csv("CSharpResults/S 5.csv")

#Medium data set results from C#
csM1 = pd.read_csv("CSharpResults/M 1.csv")
csM2 = pd.read_csv("CSharpResults/M 2.csv")
csM3 = pd.read_csv("CSharpResults/M 3.csv")
csM4 = pd.read_csv("CSharpResults/M 4.csv")
csM5 = pd.read_csv("CSharpResults/M 5.csv")

#Large data set results from C#
csL1 = pd.read_csv("CSharpResults/L 1.csv")
csL2 = pd.read_csv("CSharpResults/L 2.csv")
csL3 = pd.read_csv("CSharpResults/L 3.csv")
csL4 = pd.read_csv("CSharpResults/L 4.csv")
csL5 = pd.read_csv("CSharpResults/L 5.csv")

# %%
df = pd.DataFrame({'C++': cppL3["IndividualTime"],
                   'C#': csL3["AverageTime"]})

sns.lineplot(data = df)
# Out:
# <Axes: >
